# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# %%
# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot.
plt.plot(x_axis, y_axis, marker="D", color="green", linewidth=2, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add a grid.
plt.grid()
# Add the legend.
plt.legend()

# %%
#create a vertical bar chart
plt.bar(x_axis, y_axis, color='green', label='Boston')

#create labels fo rthe x and y axes

plt.xlabel("Date")
plt.ylabel("Fare($)")
plt.title("PyBer Fare by Month")
plt.legend()

# %%
#create the plot with ax.alt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis, color="cyan", label="Chicago")
ax.legend()

# %%
scatter = plt.scatter(x_axis, y_axis, color="red", s= [i * 3 for i in y_axis], alpha = 0.5, edgecolors = "black")

# %%
categories = ['pants','shirts','outwear','pajamas','underwear','shoes']

# %%
revenue = [25,15,5,20,10,25]

# %%
plt.pie(revenue, labels=categories, autopct="%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x233dc4cea08>,
# ...
#  [Text(0.7778174593052024, 0.7778174593052024, 'pants'),
#   Text(-0.4993895680663527, 0.9801071672559598, 'shirts'),
#   Text(-0.9801071964785992, 0.499389510713692, 'outwear'),
#   Text(-1.0461621504206509, -0.33991874768426583, 'pajamas'),
#   Text(-0.33991862524830174, -1.0461621902025062, 'underwear'),
#   Text(0.7778175139235951, -0.7778174046868057, 'shoes')],
#  [Text(0.4242640687119285, 0.4242640687119285, '25.0%'),
#   Text(-0.2723943098543742, 0.5346039094123416, '15.0%'),
#   Text(-0.5346039253519631, 0.27239427857110465, '5.0%'),
#   Text(-0.5706339002294459, -0.18541022600959953, '20.0%'),
#   Text(-0.1854101592263464, -0.5706339219286397, '10.0%'),
#   Text(0.4242640985037791, -0.4242640389200758, '25.0%')])

# %%
explode = [0, .1, 0, 0, 0, 0]

# %%
plt.pie(revenue, labels=categories, autopct="%1.1f%%", explode = explode)
# Out:
# ([<matplotlib.patches.Wedge at 0x233dc539b48>,
# ...
#  [Text(0.7778174593052024, 0.7778174593052024, 'pants'),
#   Text(-0.5447886197087484, 1.0692078188246834, 'shirts'),
#   Text(-0.9801071964785992, 0.499389510713692, 'outwear'),
#   Text(-1.0461621504206509, -0.33991874768426583, 'pajamas'),
#   Text(-0.33991862524830174, -1.0461621902025062, 'underwear'),
#   Text(0.7778175139235951, -0.7778174046868057, 'shoes')],
#  [Text(0.4242640687119285, 0.4242640687119285, '25.0%'),
#   Text(-0.3177933614967699, 0.6237045609810652, '15.0%'),
#   Text(-0.5346039253519631, 0.27239427857110465, '5.0%'),
#   Text(-0.5706339002294459, -0.18541022600959953, '20.0%'),
#   Text(-0.1854101592263464, -0.5706339219286397, '10.0%'),
#   Text(0.4242640985037791, -0.4242640389200758, '25.0%')])
